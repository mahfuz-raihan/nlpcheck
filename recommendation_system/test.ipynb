# %%
import pandas as pd
df = pd.read_csv("/home/mahfuz/Downloads/review_and_rating-2023-10-07.csv", usecols=[0, 2] )

df.tail(30)
# Out:
#         star_rating                                        review_text
# 358930            5                                                NaN
# 358931            5                                               Good
# 358932            5  টালিখাতা এপসে এখন হিসাব হয় সহজে।ধন‍্যবাদ টালিখ...
# 358933            3                                                NaN
# 358934            5                                                NaN
# 358935            5                                                NaN
# 358936            5                                                NaN
# 358937            5                                                NaN
# 358938            1                                                NaN
# 358939            5                                               Neic
# 358940            5                                                NaN
# 358941            3  লগইনের সময় এমএনপি আপডেটের অপশন টা থাকলে ভালো ...
# ...

# %%
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of         star_rating  review_title  \
# 0                 5           NaN
# 1                 5           NaN
# 2                 5           NaN
# 3                 5           NaN
# 4                 2           NaN
# ...             ...           ...
# 358955            5           NaN
# 358956            2           NaN
# 358957            5           NaN
# 358958            4           NaN
# 358959            5           NaN
#
#                                               review_text
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                               Excellent
# 4                                          Motamoti chole
# ...                                                   ...
# 358955                                          Easy life
# ...
